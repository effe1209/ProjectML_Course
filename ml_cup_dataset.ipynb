# %% [markdown]
# # Requirements

# %% [markdown]
# ## Import

# %%
# Cella 1 del Notebook
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

# Ora importi i tuoi moduli locali
from nn.network import NeuralNetwork
from nn.trainer import Trainer
from utils.losses.loss import Loss
# ...
