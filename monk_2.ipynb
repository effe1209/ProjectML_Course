# %% [markdown]
# # Monk Notebook

# %%
from __future__ import annotations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from model.network2 import NeuralNetwork
from model.trainer import Trainer
from model.losses import Loss
from utils import DataLoader
from utils import load_monk, plot_curves
from model.activations import sigmoid

np.random.seed(42) #reproducibility

# %%
# All the configurations to test for the training
# Neural Network architectures
INPUT_NEURONS = 17
OUTPUT_NEURONS = 1

HIDDEN_LAYER_SIZES = [4, 8]
HIDDEN_LAYERS_COUNTS = [1, 2]
INTERNAL_ACTIVATIONS = ['tanh', 'leaky relu', 'relu']
OUTPUT_ACTIVATIONS_AND_LOSS = [('sigmoid', 'mse'), ('identity', 'binary cross entropy sigmoid')]
NEURAL_NETWORK_CONFIGURATIONS = []

for hidden_layers_count in HIDDEN_LAYERS_COUNTS:
    for hidden_layer_size in HIDDEN_LAYER_SIZES:
        for internal_activation in INTERNAL_ACTIVATIONS:
            for output_activation, loss_function in OUTPUT_ACTIVATIONS_AND_LOSS:
                architecture = [INPUT_NEURONS] + [hidden_layer_size] * hidden_layers_count + [OUTPUT_NEURONS]
                activations = [internal_activation] * hidden_layers_count + [output_activation]
                NEURAL_NETWORK_CONFIGURATIONS.append((architecture, activations, loss_function))

# Training parameters
ETA_CONFIGURATIONS = [0.01, 0.001]
LAMBDA_CONFIGURATIONS = [0, 1e-3, 1e-4]
ALPHA_CONFIGURATIONS = [0, 0.5, 0.9]
BATCH_SIZES = [16, 32]

# Cross-validation parameters
K_FOLDS= 5
EPOCHS = 250
EARLY_STOPPING_PATIENCE = 50

# All possible configurations are tuples (NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE)
CONFIGURATIONS = []

for NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F in NEURAL_NETWORK_CONFIGURATIONS:
  for ETA in ETA_CONFIGURATIONS:
    for LAMBDA in LAMBDA_CONFIGURATIONS:
      for ALPHA in ALPHA_CONFIGURATIONS:
        for BATCH_SIZE in BATCH_SIZES:
            config = (NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE)
            CONFIGURATIONS.append(config)
LEN_CONFIGURATIONS = len(CONFIGURATIONS)

#helper function to count params that we will use later, since often we will get 100% acc, we chose the config with less parameters
def count_parameters(architecture):
    tot_params = 0
    for i in range(len(architecture) - 1):
        tot_params += architecture[i] * architecture[i+1] + architecture[i+1] # weights and bias
    return tot_params

# instability coefficient function
def val_instability_coeff(val_losses: list) -> float:
    """
    Takes val loss vec and every time val loss increases we add the diff, uses relative diff, otherwise mse would be biased
    """
    instability = 0.0
    for i in range(1, len(val_losses)):
        if val_losses[i] > val_losses[i - 1]:
            instability += (val_losses[i] - val_losses[i - 1]) / val_losses[i - 1]
    return instability

# %% [markdown]
# ## Monk 1

# %%
# Here we load the dataset and create k folds
PATH_TRAIN = 'data/monk/monks-1.train'
PATH_TEST = 'data/monk/monks-1.test'
X_train_full, y_train_full, X_test, y_test = load_monk(PATH_TRAIN, PATH_TEST)
monk_dataset_1 = DataLoader(X_train_full, y_train_full)
k_fold = monk_dataset_1.k_fold(k = K_FOLDS)

# Here we create dictionaries for storing avg accuracies and epochs on k folds, we will use them to select the best configuration
CONFIG_DICTIONARY = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY[i] = 0

CONFIG_DICTIONARY_EPOCHS = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_EPOCHS[i] = 0

CONFIG_DICTIONARY_INSTABILITY = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_INSTABILITY[i] = 0

# Cross Validation X K-folds
for i in range(LEN_CONFIGURATIONS): #iterate over all configurations
  print(f"Training {i+1}/{LEN_CONFIGURATIONS}")
  config = CONFIGURATIONS[i]
  
  for X_train, y_train, X_val, y_val in k_fold: #iterate over k folds
    NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = config
    print(f"NEURAL_NETWORK_ARCHITECTURE: {NEURAL_NETWORK_ARCHITECTURE}, NEURAL_NETWORK_ACTIVATION: {NEURAL_NETWORK_ACTIVATION}, LOSS_F: {LOSS_F}, ETA: {ETA}, LAMBDA: {LAMBDA}, ALPHA: {ALPHA}, BATCH_SIZE: {BATCH_SIZE}")
    
    #train
    nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
    trainer = Trainer(
        nn=nn,
        loss=Loss(LOSS_F),
        X_train=X_train,
        y_train=y_train, 
        X_val=X_val,
        y_val=y_val,
        epochs=EPOCHS,
        early_stopping=EARLY_STOPPING_PATIENCE, # no improvements in 50 epochs-> stop
        eta=ETA,                   # Learning rate iniziale
        lam=LAMBDA,                # L2
        alpha=ALPHA,               # Momentum
        batch_size=BATCH_SIZE,
        shuffle_batches=True
    )
    best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False) # returns the best nn based on val, the train and val loss vectors
    CONFIG_DICTIONARY_EPOCHS[i] += len(train_loss_vector) #number of epochs until early stopping or max epochs
    CONFIG_DICTIONARY_INSTABILITY[i] += val_instability_coeff(test_loss_vector)
    #best val accuracy
    out = best_nn.forward(X_val)[-1][-1]
    if LOSS_F == 'binary cross entropy sigmoid':
      out = sigmoid(out)
    predictions = np.round(out)
    print(f"Accuracy: {np.mean(predictions == y_val) * 100}%")
    CONFIG_DICTIONARY[i] += np.mean(predictions == y_val)
# Out:
# After one-hot encoding: X train full shape: (124, 17), X test shape: (432, 17), y train full shape: (124, 1), y test shape: (432, 1)
# Training 1/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# Training 2/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 3/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 76.0%
# Training 4/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 5/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# Training 6/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 68.0%
# Training 7/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 8/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 9/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 79.16666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 10/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 76.0%
# Training 11/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 12/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 80.0%
# Training 13/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 70.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 14/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# Training 15/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 60.0%
# Training 16/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 17/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 92.0%
# Training 18/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 64.0%
# Training 19/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 52.0%
# Training 20/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 60.0%
# Training 21/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 76.0%
# Training 22/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.0%
# Training 23/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 79.16666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 24/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 64.0%
# Training 25/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 44.0%
# Training 26/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 44.0%
# Training 27/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 40.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.0%
# Training 28/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 45.83333333333333%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 68.0%
# Training 29/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 52.0%
# Training 30/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 45.83333333333333%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 60.0%
# Training 31/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# Training 32/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 40.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 33/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 70.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 72.0%
# Training 34/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 76.0%
# Training 35/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 75.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 68.0%
# Training 36/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 70.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 37/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# Training 38/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 39/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 40/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 41/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 42/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# Training 43/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 68.0%
# Training 44/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 45/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 46/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 47/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 92.0%
# Training 48/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 49/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 83.33333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 80.0%
# Training 50/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 92.0%
# Training 51/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# Training 52/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 53/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# ...
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 32.0%
# Training 851/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 852/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 853/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 40.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 44.0%
# Training 854/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 80.0%
# Training 855/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 56.00000000000001%
# Training 856/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 857/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 64.0%
# Training 858/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 79.16666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 28.000000000000004%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 72.0%
# Training 859/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 32.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 37.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 48.0%
# Training 860/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 56.00000000000001%
# Training 861/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 72.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 80.0%
# Training 862/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 92.0%
# Training 863/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 864/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%

# %%
# print the top 5 configurations, sorting criterias: 1 avg accuracy, 2 n parameters (the less the better), 3 epochs trained (the less the better)
TOP_5_CONFIGS_INDEXES = sorted(CONFIG_DICTIONARY, key=lambda i: (-CONFIG_DICTIONARY[i], count_parameters(CONFIGURATIONS[i][0]), CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS))[:5]
print("Top 5 configurations:")
for i in TOP_5_CONFIGS_INDEXES:
    ACCURACY = CONFIG_DICTIONARY[i] * 100 / K_FOLDS
    print(f"Config index: {CONFIGURATIONS[i]}, Avg Epochs: {CONFIG_DICTIONARY_EPOCHS[i] // K_FOLDS}, Mean Accuracy: {ACCURACY}%, training instability coeff: {CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS}")

# Get the best configuration and its average epochs + early stop epochs to be sure it converges
NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = CONFIGURATIONS[TOP_5_CONFIGS_INDEXES[0]]
EPOCHS = CONFIG_DICTIONARY_EPOCHS[TOP_5_CONFIGS_INDEXES[0]] // K_FOLDS

nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
trainer = Trainer(
    nn=nn,
    loss=Loss(LOSS_F),
    X_train=X_train_full,
    y_train=y_train_full,
    X_val = X_test,
    y_val=y_test,
    epochs=EPOCHS,
    early_stopping=EPOCHS + 1, #can't early stop because we are using the test set as final evaluation, the +1 is to be extra sure
    eta=ETA,                   # Learning rate iniziale
    lam=LAMBDA,                # L2
    alpha=ALPHA,               # Momentum
    batch_size=BATCH_SIZE,
    shuffle_batches=True
)
# still returns the best nn, but we don-t use it for accuracy calculation nor early stopping otherwise it is data leakage
best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False)

#plot curves
plot_curves(train_loss_vector, test_loss_vector, 'loss', 'test')

# val accuracy, we can't early stop because we are using the test set as final evaluation, we can't pick the best nn, we have to use the last nn
out = nn.forward(X_test)[-1][-1]  #have to use the last trained nn, otherwise is data leakage
if LOSS_F == 'binary cross entropy sigmoid':
  out = sigmoid(out)

predictions = np.round(out)
print(f"Accuracy: {np.mean(predictions == y_test) * 100}%")
# Out:
# Top 5 configurations:
# Config index: ([17, 4, 1], ['tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0, 0.5, 32), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.3299214776605129
# Config index: ([17, 4, 1], ['tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0, 0.5, 16), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.4681612207744523
# Config index: ([17, 4, 1], ['relu', 'identity'], 'binary cross entropy sigmoid', 0.001, 0, 0.9, 16), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 1.253268180164237
# Config index: ([17, 4, 1], ['tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.0001, 0.9, 16), Avg Epochs: 115, Mean Accuracy: 100.0%, training instability coeff: 1.3050211819211492
# Config index: ([17, 4, 1], ['leaky relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0, 0.5, 16), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 1.3937712965799716
# Accuracy: 100.0%

# %% [markdown]
# ## Monk 2

# %%
# Here we load the dataset and create k folds
PATH_TRAIN = 'data/monk/monks-2.train'
PATH_TEST = 'data/monk/monks-2.test'
X_train_full, y_train_full, X_test, y_test = load_monk(PATH_TRAIN, PATH_TEST)
monk_dataset_2 = DataLoader(X_train_full, y_train_full)
k_fold = monk_dataset_2.k_fold(k = K_FOLDS)

# Here we create dictionaries for storing avg accuracies and epochs on k folds, we will use them to select the best configuration
CONFIG_DICTIONARY = {}
LEN_CONFIGURATIONS = len(CONFIGURATIONS)
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY[i] = 0

CONFIG_DICTIONARY_EPOCHS = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_EPOCHS[i] = 0

CONFIG_DICTIONARY_INSTABILITY = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_INSTABILITY[i] = 0
  
# Cross Validation X K-folds
for i in range(LEN_CONFIGURATIONS): #iterate over all configurations
  print(f"Training {i+1}/{LEN_CONFIGURATIONS}")
  config = CONFIGURATIONS[i]
  
  for X_train, y_train, X_val, y_val in k_fold: #iterate over k folds
    NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = config
    print(f"NEURAL_NETWORK_ARCHITECTURE: {NEURAL_NETWORK_ARCHITECTURE}, NEURAL_NETWORK_ACTIVATION: {NEURAL_NETWORK_ACTIVATION}, LOSS_F: {LOSS_F}, ETA: {ETA}, LAMBDA: {LAMBDA}, ALPHA: {ALPHA}, BATCH_SIZE: {BATCH_SIZE}")
    
    #train
    nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
    trainer = Trainer(
        nn=nn,
        loss=Loss(LOSS_F),
        X_train=X_train,
        y_train=y_train, 
        X_val=X_val,
        y_val=y_val,
        epochs=EPOCHS,
        early_stopping=EARLY_STOPPING_PATIENCE, # no improvements in 50 epochs-> stop
        eta=ETA,                   # Learning rate iniziale
        lam=LAMBDA,                # L2
        alpha=ALPHA,               # Momentum
        batch_size=BATCH_SIZE,
        shuffle_batches=True
    )
    best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False) # returns the best nn based on val, the train and val loss vectors
    CONFIG_DICTIONARY_EPOCHS[i] += len(train_loss_vector) #number of epochs until early stopping or max epochs
    CONFIG_DICTIONARY_INSTABILITY[i] += val_instability_coeff(test_loss_vector)

    #best val accuracy
    out = best_nn.forward(X_val)[-1][-1]
    if LOSS_F == 'binary cross entropy sigmoid':
      out = sigmoid(out)
    predictions = np.round(out)
    print(f"Accuracy: {np.mean(predictions == y_val) * 100}%")
    CONFIG_DICTIONARY[i] += np.mean(predictions == y_val)
# Out:
# After one-hot encoding: X train full shape: (169, 17), X test shape: (432, 17), y train full shape: (169, 1), y test shape: (432, 1)
# Training 1/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 69.6969696969697%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# Training 2/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 69.6969696969697%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 3/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# Training 4/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 5/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 94.11764705882352%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.23529411764706%
# Training 6/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 7/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# Training 8/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 9/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 57.57575757575758%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# Training 10/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 50.0%
# Training 11/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 94.11764705882352%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 12/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 13/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# Training 14/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# Training 15/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 42.42424242424242%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 16/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 17/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.17647058823529%
# Training 18/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 82.35294117647058%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 19/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# Training 20/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 45.45454545454545%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 21/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 41.17647058823529%
# Training 22/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# Training 23/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# Training 24/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 38.23529411764706%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 73.52941176470588%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# Training 25/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 38.23529411764706%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 48.484848484848484%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# Training 26/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 44.11764705882353%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 57.57575757575758%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# Training 27/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# Training 28/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 29/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 44.11764705882353%
# Training 30/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 31/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# Training 32/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 69.6969696969697%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 44.11764705882353%
# Training 33/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# Training 34/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 50.0%
# Training 35/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# Training 36/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# Training 37/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.23529411764706%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# Training 38/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.17647058823529%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 39/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 40/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 94.11764705882352%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 41/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.17647058823529%
# Training 42/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.17647058823529%
# Training 43/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 42.42424242424242%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 44.11764705882353%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# Training 44/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# Training 45/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 63.63636363636363%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# Training 46/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 47/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 48/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 49/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 69.6969696969697%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 44.11764705882353%
# Training 50/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 93.93939393939394%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 51/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 93.93939393939394%
# ...
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 851/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 97.05882352941177%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 852/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# Training 853/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 32.35294117647059%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 57.57575757575758%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# Training 854/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 72.72727272727273%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# Training 855/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 44.11764705882353%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 41.17647058823529%
# Training 856/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 60.60606060606061%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 44.11764705882353%
# Training 857/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 57.57575757575758%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 50.0%
# Training 858/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 58.82352941176471%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 54.54545454545454%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 64.70588235294117%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 50.0%
# Training 859/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 47.05882352941176%
# Training 860/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 67.64705882352942%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 54.54545454545454%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# Training 861/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 61.76470588235294%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 76.47058823529412%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.94117647058824%
# Training 862/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 55.88235294117647%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.94117647058824%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 47.05882352941176%
# Training 863/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 100.0%
# Training 864/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 70.58823529411765%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%

# %%
# print the top 5 configurations, sorting criterias: 1 avg accuracy, 2 n parameters (the less the better), 3 epochs trained (the less the better)
TOP_5_CONFIGS_INDEXES = sorted(CONFIG_DICTIONARY, key=lambda i: (-CONFIG_DICTIONARY[i], count_parameters(CONFIGURATIONS[i][0]), CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS))[:5]
print("Top 5 configurations:")
for i in TOP_5_CONFIGS_INDEXES:
    ACCURACY = CONFIG_DICTIONARY[i] * 100 / K_FOLDS
    print(f"Config index: {CONFIGURATIONS[i]}, Avg Epochs: {CONFIG_DICTIONARY_EPOCHS[i] // K_FOLDS}, Mean Accuracy: {ACCURACY}%, training instability coeff: {CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS}")

# Get the best configuration and its average epochs + early stop epochs to be sure it converges
NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = CONFIGURATIONS[TOP_5_CONFIGS_INDEXES[0]]
EPOCHS = CONFIG_DICTIONARY_EPOCHS[TOP_5_CONFIGS_INDEXES[0]] // K_FOLDS

nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
trainer = Trainer(
    nn=nn,
    loss=Loss(LOSS_F),
    X_train=X_train_full,
    y_train=y_train_full,
    X_val = X_test,
    y_val=y_test,
    epochs=EPOCHS,
    early_stopping=EPOCHS + 1, #can't early stop because we are using the test set as final evaluation, the +1 is to be extra sure
    eta=ETA,                   # Learning rate iniziale
    lam=LAMBDA,                # L2
    alpha=ALPHA,               # Momentum
    batch_size=BATCH_SIZE,
    shuffle_batches=True
)
# still returns the best nn, but we don-t use it for accuracy calculation nor early stopping otherwise it is data leakage
best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False)

#plot curves
plot_curves(train_loss_vector, test_loss_vector, 'loss', 'test')

# val accuracy, we can't early stop because we are using the test set as final evaluation, we can't pick the best nn, we have to use the last nn
out = nn.forward(X_test)[-1][-1]  #have to use the last trained nn, otherwise is data leakage
if LOSS_F == 'binary cross entropy sigmoid':
  out = sigmoid(out)

predictions = np.round(out)
print(f"Accuracy: {np.mean(predictions == y_test) * 100}%")
# Out:
# Top 5 configurations:
# Config index: ([17, 4, 1], ['relu', 'identity'], 'binary cross entropy sigmoid', 0.001, 0, 0.9, 32), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.06290914374322552
# Config index: ([17, 4, 1], ['leaky relu', 'identity'], 'binary cross entropy sigmoid', 0.001, 0, 0.9, 16), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.1828282956427319
# Config index: ([17, 4, 1], ['tanh', 'sigmoid'], 'mse', 0.01, 0.0001, 0.5, 32), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.2562995716107467
# Config index: ([17, 4, 1], ['leaky relu', 'sigmoid'], 'mse', 0.01, 0, 0.9, 32), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.31921540658275144
# Config index: ([17, 4, 1], ['tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.0001, 0.5, 32), Avg Epochs: 250, Mean Accuracy: 100.0%, training instability coeff: 0.3353466328330569
# Accuracy: 100.0%

# %% [markdown]
# ## Monk 3

# %%
# Here we load the dataset and create k folds
PATH_TRAIN = 'data/monk/monks-3.train'
PATH_TEST = 'data/monk/monks-3.test'
X_train_full, y_train_full, X_test, y_test = load_monk(PATH_TRAIN, PATH_TEST)
monk_dataset_3 = DataLoader(X_train_full, y_train_full)
k_fold = monk_dataset_3.k_fold(k = K_FOLDS)

# Here we create dictionaries for storing avg accuracies and epochs on k folds, we will use them to select the best configuration
CONFIG_DICTIONARY = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY[i] = 0

CONFIG_DICTIONARY_EPOCHS = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_EPOCHS[i] = 0

CONFIG_DICTIONARY_INSTABILITY = {}
for i in range(LEN_CONFIGURATIONS):
  CONFIG_DICTIONARY_INSTABILITY[i] = 0
  
# Cross Validation X K-folds
for i in range(LEN_CONFIGURATIONS): #iterate over all configurations
  print(f"Training {i+1}/{LEN_CONFIGURATIONS}")
  config = CONFIGURATIONS[i]
  
  for X_train, y_train, X_val, y_val in k_fold: #iterate over k folds
    NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = config
    print(f"NEURAL_NETWORK_ARCHITECTURE: {NEURAL_NETWORK_ARCHITECTURE}, NEURAL_NETWORK_ACTIVATION: {NEURAL_NETWORK_ACTIVATION}, LOSS_F: {LOSS_F}, ETA: {ETA}, LAMBDA: {LAMBDA}, ALPHA: {ALPHA}, BATCH_SIZE: {BATCH_SIZE}")
    
    #train
    nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
    trainer = Trainer(
        nn=nn,
        loss=Loss(LOSS_F),
        X_train=X_train,
        y_train=y_train, 
        X_val=X_val,
        y_val=y_val,
        epochs=EPOCHS,
        early_stopping=EARLY_STOPPING_PATIENCE, # no improvements in 50 epochs-> stop
        eta=ETA,                   # Learning rate iniziale
        lam=LAMBDA,                # L2
        alpha=ALPHA,               # Momentum
        batch_size=BATCH_SIZE,
        shuffle_batches=True
    )
    best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False) # returns the best nn based on val, the train and val loss vectors
    CONFIG_DICTIONARY_EPOCHS[i] += len(train_loss_vector) #number of epochs until early stopping or max epochs
    CONFIG_DICTIONARY_INSTABILITY[i] += val_instability_coeff(test_loss_vector)

    #best val accuracy
    out = best_nn.forward(X_val)[-1][-1]
    if LOSS_F == 'binary cross entropy sigmoid':
      out = sigmoid(out)
    predictions = np.round(out)
    print(f"Accuracy: {np.mean(predictions == y_val) * 100}%")
    CONFIG_DICTIONARY[i] += np.mean(predictions == y_val)
# Out:
# After one-hot encoding: X train full shape: (122, 17), X test shape: (432, 17), y train full shape: (122, 1), y test shape: (432, 1)
# Training 1/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 2/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 3/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# Training 4/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 5/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 6/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 7/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 8/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 9/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 10/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 11/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 12/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 13/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 14/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 15/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 16/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 17/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 18/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 19/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 28.000000000000004%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 20/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 75.0%
# Training 21/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# Training 22/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 62.5%
# Training 23/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# Training 24/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 25/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 32.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 66.66666666666666%
# Training 26/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 40.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 37.5%
# Training 27/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 60.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 45.83333333333333%
# Training 28/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 37.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 79.16666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 33.33333333333333%
# Training 29/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 33.33333333333333%
# Training 30/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 31/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 32.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 32/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 76.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 45.83333333333333%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 33/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 62.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 34/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 35/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 36/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'sigmoid'], LOSS_F: mse, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 37/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 38/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 39/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 40/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 41/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 42/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 100.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 43/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 44/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 45/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 46/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 47/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 48/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 49/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 50/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 51/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 4, 1], NEURAL_NETWORK_ACTIVATION: ['tanh', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.01, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 52/864
# ...
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 851/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 852/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 853/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 45.83333333333333%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 68.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# Training 854/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 64.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 66.66666666666666%
# Training 855/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 48.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 54.166666666666664%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 50.0%
# Training 856/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 45.83333333333333%
# Training 857/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 32.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 44.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 33.33333333333333%
# Training 858/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 50.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 859/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 16
# Accuracy: 33.33333333333333%
# Training 860/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# Training 861/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 41.66666666666667%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 84.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# Training 862/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 58.333333333333336%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 92.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 52.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.5, BATCH_SIZE: 32
# Accuracy: 87.5%
# Training 863/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 88.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 16
# Accuracy: 91.66666666666666%
# Training 864/864
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 95.83333333333334%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 96.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 87.5%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 80.0%
# NEURAL_NETWORK_ARCHITECTURE: [17, 8, 8, 1], NEURAL_NETWORK_ACTIVATION: ['relu', 'relu', 'identity'], LOSS_F: binary cross entropy sigmoid, ETA: 0.001, LAMBDA: 0.0001, ALPHA: 0.9, BATCH_SIZE: 32
# Accuracy: 91.66666666666666%

# %%
# print the top 10 configurations, sorting criterias: 1 avg accuracy, 2 n parameters (the less the better), 3 epochs trained (the less the better)
TOP_10_CONFIGS_INDEXES = sorted(CONFIG_DICTIONARY, key=lambda i: (-CONFIG_DICTIONARY[i], count_parameters(CONFIGURATIONS[i][0]), CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS))[:10]
print("Top 10 configurations:")
for i in TOP_10_CONFIGS_INDEXES:
    ACCURACY = CONFIG_DICTIONARY[i] * 100 / K_FOLDS
    print(f"Config index: {CONFIGURATIONS[i]}, Avg Epochs: {CONFIG_DICTIONARY_EPOCHS[i] // K_FOLDS}, Mean Accuracy: {ACCURACY}%, training instability coeff: {CONFIG_DICTIONARY_INSTABILITY[i] / K_FOLDS}")
# Out:
# Top 10 configurations:
# Config index: ([17, 4, 1], ['relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.0001, 0.9, 16), Avg Epochs: 99, Mean Accuracy: 95.96666666666667%, training instability coeff: 12.473059309636598
# Config index: ([17, 4, 4, 1], ['relu', 'relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.001, 0.5, 16), Avg Epochs: 87, Mean Accuracy: 95.06666666666666%, training instability coeff: 4.478921643986516
# Config index: ([17, 8, 8, 1], ['leaky relu', 'leaky relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.001, 0, 32), Avg Epochs: 89, Mean Accuracy: 95.06666666666666%, training instability coeff: 2.0584998976103512
# Config index: ([17, 4, 4, 1], ['leaky relu', 'leaky relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0, 0.5, 16), Avg Epochs: 100, Mean Accuracy: 94.3%, training instability coeff: 6.336201988183554
# Config index: ([17, 8, 1], ['leaky relu', 'sigmoid'], 'mse', 0.01, 0.0001, 0.9, 16), Avg Epochs: 73, Mean Accuracy: 94.3%, training instability coeff: 1.2312056148371364
# Config index: ([17, 4, 1], ['tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.0001, 0.9, 32), Avg Epochs: 91, Mean Accuracy: 94.26666666666667%, training instability coeff: 1.7223664097333695
# Config index: ([17, 4, 1], ['leaky relu', 'sigmoid'], 'mse', 0.01, 0, 0.9, 32), Avg Epochs: 82, Mean Accuracy: 94.26666666666667%, training instability coeff: 3.144422629499833
# Config index: ([17, 4, 4, 1], ['tanh', 'tanh', 'identity'], 'binary cross entropy sigmoid', 0.01, 0, 0, 16), Avg Epochs: 77, Mean Accuracy: 94.26666666666667%, training instability coeff: 0.8410671902919968
# Config index: ([17, 4, 4, 1], ['relu', 'relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.001, 0, 16), Avg Epochs: 96, Mean Accuracy: 94.26666666666667%, training instability coeff: 2.0891805659273013
# Config index: ([17, 4, 4, 1], ['leaky relu', 'leaky relu', 'identity'], 'binary cross entropy sigmoid', 0.01, 0.0001, 0.5, 16), Avg Epochs: 95, Mean Accuracy: 94.26666666666667%, training instability coeff: 4.7839313664456675

# %%
# Get the best configuration and its average epochs + early stop epochs to be sure it converges
NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE = CONFIGURATIONS[TOP_10_CONFIGS_INDEXES[7]]
ETA = ETA/3
LAMBDA = LAMBDA * 3
EPOCHS = CONFIG_DICTIONARY_EPOCHS[TOP_10_CONFIGS_INDEXES[7]] // K_FOLDS

nn = NeuralNetwork(NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION)
trainer = Trainer(
    nn=nn,
    loss=Loss(LOSS_F),
    X_train=X_train_full,
    y_train=y_train_full,
    X_val = X_test,
    y_val=y_test,
    epochs=EPOCHS,
    early_stopping=EPOCHS + 1, #can't early stop because we are using the test set as final evaluation, the +1 is to be extra sure
    eta=ETA,                   # Learning rate iniziale
    lam=LAMBDA,                # L2
    alpha=ALPHA,               # Momentum
    batch_size=BATCH_SIZE,
    shuffle_batches=True
)
# still returns the best nn, but we don-t use it for accuracy calculation nor early stopping otherwise it is data leakage
best_nn, train_loss_vector, test_loss_vector = trainer.train(print_epochs=False)

#plot curves
plot_curves(train_loss_vector, test_loss_vector, 'loss', 'test')

# val accuracy, we can't early stop because we are using the test set as final evaluation, we can't pick the best nn, we have to use the last nn
out = nn.forward(X_test)[-1][-1]  #have to use the last trained nn, otherwise is data leakage
if LOSS_F == 'binary cross entropy sigmoid':
  out = sigmoid(out)

predictions = np.round(out)
print(f"Accuracy: {np.mean(predictions == y_test) * 100}%")
# Out:
# Accuracy: 95.37037037037037%
