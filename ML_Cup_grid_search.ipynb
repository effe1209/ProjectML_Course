# %% [markdown]
# # ML Cup Notebook

# %%
from __future__ import annotations
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from model.network import NeuralNetwork
from model.trainer import Trainer
from model.losses import Loss, mee
from utils import DataLoader
from utils import plot_curves
from utils import StandardScaler
from utils.model_selection_helpers import instability_coeff, tran_val_diff, count_parameters
from utils.grid_search import grid_search_mlcup
import copy
from IPython.display import clear_output

np.random.seed(8) # for reproducibility, we are not choosing a 'good seed for rigging experiments', just my lucky number =)

# %%
# Load Data
PATH = 'data/ML CUP/ML-CUP25-TR.csv'
df = pd.read_csv(PATH, comment='#', header=None)

dataset = np.array(df)
X = dataset[:, 1:-4]
y = dataset[:, -4:]

print(f"X.shape: {X.shape}, y.shape: {y.shape} ")
train_test_dataset = DataLoader(X, y)
X_train, y_train, X_test, y_test = train_test_dataset.train_val_split(portion = 0.8, shuffle = True)
print(f"X_train.shape: {X_train.shape}, y_train.shape: {y_train.shape}, X_test.shape: {X_test.shape}, y_test.shape: {y_test.shape}")
train_val_dataset = DataLoader(X_train, y_train)
# Out:
# X.shape: (500, 12), y.shape: (500, 4)
# X_train.shape: (400, 12), y_train.shape: (400, 4), X_test.shape: (100, 12), y_test.shape: (100, 4)

# %%
# All the configurations to test for the training
# Neural Network architectures
INPUT_NEURONS = 12
OUTPUT_NEURONS = 4

HIDDEN_LAYER_SIZES = [16, 32]
HIDDEN_LAYERS_COUNTS = [1, 2, 3]
INTERNAL_ACTIVATIONS = ['tanh', 'leaky relu', 'relu']
OUTPUT_ACTIVATIONS_AND_LOSS = [('identity', 'mse')]
NEURAL_NETWORK_CONFIGURATIONS = []

for hidden_layers_count in HIDDEN_LAYERS_COUNTS:
    for hidden_layer_size in HIDDEN_LAYER_SIZES:
        for internal_activation in INTERNAL_ACTIVATIONS:
            for output_activation, loss_function in OUTPUT_ACTIVATIONS_AND_LOSS:
                architecture = [INPUT_NEURONS] + [hidden_layer_size] * hidden_layers_count + [OUTPUT_NEURONS]
                activations = [internal_activation] * hidden_layers_count + [output_activation]
                NEURAL_NETWORK_CONFIGURATIONS.append((architecture, activations, loss_function))

# Training parameters
ETA_CONFIGURATIONS =[0.01, 0.001]
LAMBDA_CONFIGURATIONS =[0, 1e-4, 1e-6] # we have to make them small because they are independent of eta
ALPHA_CONFIGURATIONS = [0, 0.5, 0.9]
BATCH_SIZES =  [32] #we won't fine tune the batch size for time constraints

# Cross-validation parameters
K_FOLDS= 5
EPOCHS = 500
EARLY_STOPPING_PATIENCE = 100

# All possible configurations are tuples (NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE)
CONFIGURATIONS = []

for NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F in NEURAL_NETWORK_CONFIGURATIONS:
  for ETA in ETA_CONFIGURATIONS:
    for LAMBDA in LAMBDA_CONFIGURATIONS:
      for ALPHA in ALPHA_CONFIGURATIONS:
        for BATCH_SIZE in BATCH_SIZES:
            config = (NEURAL_NETWORK_ARCHITECTURE, NEURAL_NETWORK_ACTIVATION, LOSS_F, ETA, LAMBDA, ALPHA, BATCH_SIZE)
            CONFIGURATIONS.append(config)
LEN_CONFIGURATIONS = len(CONFIGURATIONS)

# We use this to train the nn with only one output neuron
CONFIGURATIONS_OUT_1 = copy.deepcopy(CONFIGURATIONS)
for config in CONFIGURATIONS_OUT_1:
    architecture, activations, loss_f, eta, lambd, alpha, batch_size = config
    architecture[-1] = 1  # change output neurons to 1

print(f"Total configurations: {LEN_CONFIGURATIONS}")
# Out:
# Total configurations: 324

# %%
def print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS):
    # print the top 25 configurations, sorting criterias: 1 avg mee
    valid_id = [i for i in CONFIG_DICTIONARY if not np.isnan(CONFIG_DICTIONARY[i])] #sometimes gradient explodes and mee is nan
    TOP_25_CONFIGS_INDEXES = sorted(valid_id, key=lambda i: CONFIG_DICTIONARY[i])[:25]
    print("Top 25 configurations:")
    for i in TOP_25_CONFIGS_INDEXES:
        MEE = CONFIG_DICTIONARY[i]/ K_FOLDS
        print(f'''Config index: {CONFIGURATIONS[i]}, Avg Epochs: {CONFIG_DICTIONARY_EPOCHS[i] // K_FOLDS}, Mean MEE: {MEE}%,
            training instability coeff validation: {CONFIG_DICTIONARY_INSTABILITY_VAL[i] / K_FOLDS}, 
            training instability coeff train: {CONFIG_DICTIONARY_INSTABILITY_TRAIN[i] / K_FOLDS}, 
            training loss-val loss diff: {CONFIG_DICTIONARY_TRAIN_LOSS_DIFF[i] / K_FOLDS}, 
            Mean Epochs: {CONFIG_DICTIONARY_EPOCHS[i] // K_FOLDS},
            Mean Test Loss (not rescaled): {np.mean(CONFIG_DICTIONARY_TEST_LOSS[i])},
            Std Test Loss (not rescaled): {np.std(CONFIG_DICTIONARY_TEST_LOSS[i])}
            ''')

# %% [markdown]
# ## 1 Neural Network for classification

# %%
k_fold = train_val_dataset.k_fold(k = K_FOLDS)
grid_s_outputs =  grid_search_mlcup(LEN_CONFIGURATIONS, CONFIGURATIONS, k_fold, EPOCHS, EARLY_STOPPING_PATIENCE)
CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS = grid_s_outputs
clear_output(wait=False)
print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS)
# Out:
# Top 25 configurations:
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 197, Mean MEE: 21.086128127322805%,
#             training instability coeff validation: 6.718068383147505,
#             training instability coeff train: 2.8847336568257016,
#             training loss-val loss diff: 21.176896658767543,
#             Mean Epochs: 197,
#             Mean Test Loss (not rescaled): 0.4620858954590549,
#             Std Test Loss (not rescaled): 0.0462047391932604
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 205, Mean MEE: 21.352102145430102%,
#             training instability coeff validation: 7.037332852119496,
#             training instability coeff train: 3.149126223942718,
#             training loss-val loss diff: 24.474168238208758,
#             Mean Epochs: 205,
#             Mean Test Loss (not rescaled): 0.4615695825677557,
#             Std Test Loss (not rescaled): 0.031207981097678014
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 169, Mean MEE: 21.352524130538466%,
#             training instability coeff validation: 5.968133575603665,
#             training instability coeff train: 2.75958991257074,
#             training loss-val loss diff: 22.408017980855668,
#             Mean Epochs: 169,
#             Mean Test Loss (not rescaled): 0.4556672475226792,
#             Std Test Loss (not rescaled): 0.05036009566790146
#
# Config index: ([12, 16, 16, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 215, Mean MEE: 21.45502505025231%,
#             training instability coeff validation: 6.508641206017185,
#             training instability coeff train: 2.490393326031872,
#             training loss-val loss diff: 21.53237651488824,
#             Mean Epochs: 215,
#             Mean Test Loss (not rescaled): 0.4573585112435343,
#             Std Test Loss (not rescaled): 0.024746185678732435
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 201, Mean MEE: 21.528033355581947%,
#             training instability coeff validation: 6.333836400676253,
#             training instability coeff train: 1.9781601922769567,
#             training loss-val loss diff: 24.170783226498074,
#             Mean Epochs: 201,
#             Mean Test Loss (not rescaled): 0.46765365699672745,
#             Std Test Loss (not rescaled): 0.05572478010361609
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.01, 0.0001, 0.5, 32), Avg Epochs: 208, Mean MEE: 21.529010502800283%,
#             training instability coeff validation: 13.61677671614045,
#             training instability coeff train: 7.263749642863776,
#             training loss-val loss diff: 21.51298645407514,
#             Mean Epochs: 208,
#             Mean Test Loss (not rescaled): 0.47100102288846096,
#             Std Test Loss (not rescaled): 0.06216104412213657
#
# Config index: ([12, 16, 4], ['tanh', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 204, Mean MEE: 21.58796803573737%,
#             training instability coeff validation: 5.843029072899139,
#             training instability coeff train: 2.2431275396894166,
#             training loss-val loss diff: 17.795036595692004,
#             Mean Epochs: 204,
#             Mean Test Loss (not rescaled): 0.45503395445480743,
#             Std Test Loss (not rescaled): 0.0319500318275089
#
# Config index: ([12, 32, 32, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 176, Mean MEE: 21.588060460690578%,
#             training instability coeff validation: 5.714730331250505,
#             training instability coeff train: 2.1654866520178175,
#             training loss-val loss diff: 17.024923024112717,
#             Mean Epochs: 176,
#             Mean Test Loss (not rescaled): 0.4535814165654194,
#             Std Test Loss (not rescaled): 0.048960136705966315
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 209, Mean MEE: 21.637473413155686%,
#             training instability coeff validation: 5.341217176625011,
#             training instability coeff train: 2.123143779037131,
#             training loss-val loss diff: 24.375805038178406,
#             Mean Epochs: 209,
#             Mean Test Loss (not rescaled): 0.4568397707968156,
#             Std Test Loss (not rescaled): 0.023540171756420047
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 168, Mean MEE: 21.65551174283737%,
#             training instability coeff validation: 6.552552584343118,
#             training instability coeff train: 3.583616188360935,
#             training loss-val loss diff: 26.51521391486083,
#             Mean Epochs: 168,
#             Mean Test Loss (not rescaled): 0.4592376990264012,
#             Std Test Loss (not rescaled): 0.02771912384016017
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 246, Mean MEE: 21.67522439059756%,
#             training instability coeff validation: 4.726970637058031,
#             training instability coeff train: 1.4696214024587015,
#             training loss-val loss diff: 22.93363550459111,
#             Mean Epochs: 246,
#             Mean Test Loss (not rescaled): 0.4491404163374419,
#             Std Test Loss (not rescaled): 0.030438835664392348
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 150, Mean MEE: 21.70493653025232%,
#             training instability coeff validation: 5.900881656141822,
#             training instability coeff train: 3.2181434006435197,
#             training loss-val loss diff: 22.271933488748274,
#             Mean Epochs: 150,
#             Mean Test Loss (not rescaled): 0.47143544791108577,
#             Std Test Loss (not rescaled): 0.02716164457011905
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 180, Mean MEE: 21.74364895032992%,
#             training instability coeff validation: 5.733481798765645,
#             training instability coeff train: 2.4755205520574792,
#             training loss-val loss diff: 17.924911279021508,
#             Mean Epochs: 180,
#             Mean Test Loss (not rescaled): 0.46531113159790616,
#             Std Test Loss (not rescaled): 0.05643130663923366
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 163, Mean MEE: 21.76863970048023%,
#             training instability coeff validation: 5.221032951271314,
#             training instability coeff train: 2.3911586824596496,
#             training loss-val loss diff: 21.627159258121335,
#             Mean Epochs: 163,
#             Mean Test Loss (not rescaled): 0.47066276964534143,
#             Std Test Loss (not rescaled): 0.01646355157416509
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 249, Mean MEE: 21.810708678825637%,
#             training instability coeff validation: 4.975040955306056,
#             training instability coeff train: 1.530741700789901,
#             training loss-val loss diff: 21.61316645532666,
#             Mean Epochs: 249,
#             Mean Test Loss (not rescaled): 0.4698503741199461,
#             Std Test Loss (not rescaled): 0.05002998300939069
#
# Config index: ([12, 16, 16, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 184, Mean MEE: 21.84228601963755%,
#             training instability coeff validation: 5.401242056311657,
#             training instability coeff train: 2.1162780471370413,
#             training loss-val loss diff: 17.284882434368768,
#             Mean Epochs: 184,
#             Mean Test Loss (not rescaled): 0.476035234112702,
#             Std Test Loss (not rescaled): 0.06396717152034087
#
# Config index: ([12, 32, 4], ['tanh', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 206, Mean MEE: 21.867807539581445%,
#             training instability coeff validation: 6.5364773375591625,
#             training instability coeff train: 2.5218261580784045,
#             training loss-val loss diff: 18.592750529306866,
#             Mean Epochs: 206,
#             Mean Test Loss (not rescaled): 0.47416031756816396,
#             Std Test Loss (not rescaled): 0.06452655827373768
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 180, Mean MEE: 21.87443897094035%,
#             training instability coeff validation: 7.38821753435429,
#             training instability coeff train: 2.9922981030567386,
#             training loss-val loss diff: 19.331565821232292,
#             Mean Epochs: 180,
#             Mean Test Loss (not rescaled): 0.4779711226326067,
#             Std Test Loss (not rescaled): 0.06284923645823383
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 213, Mean MEE: 21.874986689073786%,
#             training instability coeff validation: 4.6948063583967565,
#             training instability coeff train: 1.276166668843443,
#             training loss-val loss diff: 21.293968641732892,
#             Mean Epochs: 213,
#             Mean Test Loss (not rescaled): 0.4766489435271775,
#             Std Test Loss (not rescaled): 0.07687389759723334
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.01, 0, 0.5, 32), Avg Epochs: 208, Mean MEE: 21.895787971893064%,
#             training instability coeff validation: 12.16618144053522,
#             training instability coeff train: 7.424508718459639,
#             training loss-val loss diff: 25.819403228221127,
#             Mean Epochs: 208,
#             Mean Test Loss (not rescaled): 0.48511028748057783,
#             Std Test Loss (not rescaled): 0.06242678263879732
#
# Config index: ([12, 16, 4], ['tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 223, Mean MEE: 21.99921691413997%,
#             training instability coeff validation: 5.895483347379968,
#             training instability coeff train: 2.303853859113917,
#             training loss-val loss diff: 18.944351449630666,
#             Mean Epochs: 223,
#             Mean Test Loss (not rescaled): 0.49196976213174554,
#             Std Test Loss (not rescaled): 0.09478412232711403
#
# Config index: ([12, 32, 4], ['tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 198, Mean MEE: 21.999688516734675%,
#             training instability coeff validation: 5.570807069780757,
#             training instability coeff train: 2.26163541085708,
#             training loss-val loss diff: 15.973824181367684,
#             Mean Epochs: 198,
#             Mean Test Loss (not rescaled): 0.4806648064562517,
#             Std Test Loss (not rescaled): 0.08225312347969974
#
# Config index: ([12, 32, 32, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 269, Mean MEE: 22.00302516098237%,
#             training instability coeff validation: 4.854866804721222,
#             training instability coeff train: 1.2678731845898326,
#             training loss-val loss diff: 19.35666260466868,
#             Mean Epochs: 269,
#             Mean Test Loss (not rescaled): 0.4860116233977513,
#             Std Test Loss (not rescaled): 0.07901890319444889
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 189, Mean MEE: 22.005723210734267%,
#             training instability coeff validation: 4.994225951764725,
#             training instability coeff train: 1.7401407899532526,
#             training loss-val loss diff: 21.668725231592738,
#             Mean Epochs: 189,
#             Mean Test Loss (not rescaled): 0.48559894042907137,
#             Std Test Loss (not rescaled): 0.03411216131169549
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 216, Mean MEE: 22.016251305632778%,
#             training instability coeff validation: 7.759055958103929,
#             training instability coeff train: 3.9693507434304394,
#             training loss-val loss diff: 24.958120170326374,
#             Mean Epochs: 216,
#             Mean Test Loss (not rescaled): 0.4886431968965635,
#             Std Test Loss (not rescaled): 0.03449104327527393

# %% [markdown]
# ## 4 Neural Networks for classification

# %% [markdown]
# ### y 0 pred

# %%
y_0 = np.reshape(y_train[:,0], (-1, 1))
train_val_dataset_y0 = DataLoader(X_train, y_0)
k_fold = train_val_dataset_y0.k_fold(k = K_FOLDS)
grid_s_outputs =  grid_search_mlcup(LEN_CONFIGURATIONS, CONFIGURATIONS_OUT_1, k_fold, EPOCHS, EARLY_STOPPING_PATIENCE)
CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS = grid_s_outputs
clear_output(wait=False)
print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS)
# Out:
# Top 25 configurations:
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 212, Mean MEE: 6.434529320250364%,
#             training instability coeff validation: 22.871468077768174,
#             training instability coeff train: 12.718210606646071,
#             training loss-val loss diff: 24.689440075237535,
#             Mean Epochs: 212,
#             Mean Test Loss (not rescaled): 0.3625352423985309,
#             Std Test Loss (not rescaled): 0.07036548671648388
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 239, Mean MEE: 6.717121662200228%,
#             training instability coeff validation: 20.67136142488769,
#             training instability coeff train: 12.633494600274535,
#             training loss-val loss diff: 37.4645956417088,
#             Mean Epochs: 239,
#             Mean Test Loss (not rescaled): 0.44767953341807754,
#             Std Test Loss (not rescaled): 0.09633797332708553
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 200, Mean MEE: 6.760539051458972%,
#             training instability coeff validation: 18.706544923040408,
#             training instability coeff train: 9.591185493944849,
#             training loss-val loss diff: 28.40643405265319,
#             Mean Epochs: 200,
#             Mean Test Loss (not rescaled): 0.402624255912764,
#             Std Test Loss (not rescaled): 0.07156169052341783
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 184, Mean MEE: 6.7811161757720955%,
#             training instability coeff validation: 17.403655293120373,
#             training instability coeff train: 10.078275202918167,
#             training loss-val loss diff: 19.240870612537382,
#             Mean Epochs: 184,
#             Mean Test Loss (not rescaled): 0.39647842614564394,
#             Std Test Loss (not rescaled): 0.06023701889856342
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 199, Mean MEE: 6.79622075620812%,
#             training instability coeff validation: 15.095074737843467,
#             training instability coeff train: 8.224401015250892,
#             training loss-val loss diff: 19.076419850919574,
#             Mean Epochs: 199,
#             Mean Test Loss (not rescaled): 0.4075196667596293,
#             Std Test Loss (not rescaled): 0.08581425461795202
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 173, Mean MEE: 6.821399244655585%,
#             training instability coeff validation: 12.749183669876931,
#             training instability coeff train: 8.113523469088925,
#             training loss-val loss diff: 24.20252032263643,
#             Mean Epochs: 173,
#             Mean Test Loss (not rescaled): 0.4149383361598435,
#             Std Test Loss (not rescaled): 0.06786788788594347
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 228, Mean MEE: 6.822253448591717%,
#             training instability coeff validation: 15.525201332535847,
#             training instability coeff train: 8.523954347177854,
#             training loss-val loss diff: 28.020495710831902,
#             Mean Epochs: 228,
#             Mean Test Loss (not rescaled): 0.414298280841627,
#             Std Test Loss (not rescaled): 0.09434048500912236
#
# Config index: ([12, 32, 4], ['tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 190, Mean MEE: 6.823574543810369%,
#             training instability coeff validation: 13.39855262939528,
#             training instability coeff train: 7.774089116706702,
#             training loss-val loss diff: 19.300938563898942,
#             Mean Epochs: 190,
#             Mean Test Loss (not rescaled): 0.39333472807705017,
#             Std Test Loss (not rescaled): 0.055805423195947314
#
# Config index: ([12, 32, 32, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 192, Mean MEE: 6.837363828633559%,
#             training instability coeff validation: 14.51733657482838,
#             training instability coeff train: 6.388190257107867,
#             training loss-val loss diff: 18.997069631499635,
#             Mean Epochs: 192,
#             Mean Test Loss (not rescaled): 0.3974737038743157,
#             Std Test Loss (not rescaled): 0.09234024365719394
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 199, Mean MEE: 6.859868845520644%,
#             training instability coeff validation: 14.094133953959002,
#             training instability coeff train: 7.476549469046338,
#             training loss-val loss diff: 22.508818285503953,
#             Mean Epochs: 199,
#             Mean Test Loss (not rescaled): 0.42250679066294683,
#             Std Test Loss (not rescaled): 0.05697959560005044
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 207, Mean MEE: 6.861753318208519%,
#             training instability coeff validation: 21.366390014487425,
#             training instability coeff train: 12.86614476345271,
#             training loss-val loss diff: 27.857126280675345,
#             Mean Epochs: 207,
#             Mean Test Loss (not rescaled): 0.40923740677640985,
#             Std Test Loss (not rescaled): 0.10853018133670714
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 221, Mean MEE: 6.874673077568448%,
#             training instability coeff validation: 19.25801032135471,
#             training instability coeff train: 13.670553508198982,
#             training loss-val loss diff: 31.302532470732693,
#             Mean Epochs: 221,
#             Mean Test Loss (not rescaled): 0.43138715470401545,
#             Std Test Loss (not rescaled): 0.06035750311511727
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 258, Mean MEE: 6.905292233638616%,
#             training instability coeff validation: 19.547278747949964,
#             training instability coeff train: 11.262742113158046,
#             training loss-val loss diff: 22.616544098748236,
#             Mean Epochs: 258,
#             Mean Test Loss (not rescaled): 0.4050691827976137,
#             Std Test Loss (not rescaled): 0.09107873492493497
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 209, Mean MEE: 6.912803585568824%,
#             training instability coeff validation: 16.1409643432856,
#             training instability coeff train: 9.407141753615608,
#             training loss-val loss diff: 27.788061208894966,
#             Mean Epochs: 209,
#             Mean Test Loss (not rescaled): 0.4198563895153387,
#             Std Test Loss (not rescaled): 0.0995835141507869
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 184, Mean MEE: 6.913712396857553%,
#             training instability coeff validation: 13.734849442330846,
#             training instability coeff train: 8.247080323628671,
#             training loss-val loss diff: 24.71488388857927,
#             Mean Epochs: 184,
#             Mean Test Loss (not rescaled): 0.39833898504342125,
#             Std Test Loss (not rescaled): 0.07290516916139289
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 185, Mean MEE: 6.913822326970032%,
#             training instability coeff validation: 16.58026533822872,
#             training instability coeff train: 8.341134497769662,
#             training loss-val loss diff: 19.537182881699067,
#             Mean Epochs: 185,
#             Mean Test Loss (not rescaled): 0.42239449569877996,
#             Std Test Loss (not rescaled): 0.07543749297461388
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 206, Mean MEE: 6.923562894850048%,
#             training instability coeff validation: 15.662984083250171,
#             training instability coeff train: 8.603288456949766,
#             training loss-val loss diff: 26.635359757797527,
#             Mean Epochs: 206,
#             Mean Test Loss (not rescaled): 0.4243998424202001,
#             Std Test Loss (not rescaled): 0.10318177770595864
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 216, Mean MEE: 6.930130733655472%,
#             training instability coeff validation: 13.588392119253186,
#             training instability coeff train: 8.27430336547733,
#             training loss-val loss diff: 24.21443444750819,
#             Mean Epochs: 216,
#             Mean Test Loss (not rescaled): 0.45868720040363076,
#             Std Test Loss (not rescaled): 0.1433950372970196
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 222, Mean MEE: 6.932420084308802%,
#             training instability coeff validation: 19.19617478632855,
#             training instability coeff train: 13.295092560064177,
#             training loss-val loss diff: 38.32341278161429,
#             Mean Epochs: 222,
#             Mean Test Loss (not rescaled): 0.41377315594799774,
#             Std Test Loss (not rescaled): 0.057609504472656725
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 186, Mean MEE: 6.9378337868181985%,
#             training instability coeff validation: 16.889743978925495,
#             training instability coeff train: 10.344020813550024,
#             training loss-val loss diff: 24.94934839490583,
#             Mean Epochs: 186,
#             Mean Test Loss (not rescaled): 0.4551147720377552,
#             Std Test Loss (not rescaled): 0.07750089279855074
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 204, Mean MEE: 6.952776925849738%,
#             training instability coeff validation: 17.121940782131183,
#             training instability coeff train: 8.101291117561209,
#             training loss-val loss diff: 22.245965813522183,
#             Mean Epochs: 204,
#             Mean Test Loss (not rescaled): 0.4350454372597728,
#             Std Test Loss (not rescaled): 0.08941594914431203
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 191, Mean MEE: 6.972061657948297%,
#             training instability coeff validation: 17.29067712341141,
#             training instability coeff train: 12.498720660083602,
#             training loss-val loss diff: 36.84864222009118,
#             Mean Epochs: 191,
#             Mean Test Loss (not rescaled): 0.4511610907944867,
#             Std Test Loss (not rescaled): 0.0684907906250161
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 211, Mean MEE: 6.9736578644435925%,
#             training instability coeff validation: 17.039207888194788,
#             training instability coeff train: 10.05485675392418,
#             training loss-val loss diff: 25.935730197901346,
#             Mean Epochs: 211,
#             Mean Test Loss (not rescaled): 0.42134395673659697,
#             Std Test Loss (not rescaled): 0.06351531818675128
#
# Config index: ([12, 32, 32, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 156, Mean MEE: 6.991157387076571%,
#             training instability coeff validation: 12.345477419180177,
#             training instability coeff train: 7.720393754809203,
#             training loss-val loss diff: 19.461716202015083,
#             Mean Epochs: 156,
#             Mean Test Loss (not rescaled): 0.4205255054964443,
#             Std Test Loss (not rescaled): 0.08108289120815941
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 230, Mean MEE: 6.992052150626764%,
#             training instability coeff validation: 19.28542232702265,
#             training instability coeff train: 10.204870776632742,
#             training loss-val loss diff: 24.94155864755826,
#             Mean Epochs: 230,
#             Mean Test Loss (not rescaled): 0.4364853933108489,
#             Std Test Loss (not rescaled): 0.09262466931706237

# %% [markdown]
# ### y 1 pred

# %%
y_1 = np.reshape(y_train[:,1], (-1, 1))
train_val_dataset_y1 = DataLoader(X_train, y_1)
k_fold = train_val_dataset_y1.k_fold(k = K_FOLDS)
grid_s_outputs =  grid_search_mlcup(LEN_CONFIGURATIONS, CONFIGURATIONS_OUT_1, k_fold, EPOCHS, EARLY_STOPPING_PATIENCE)
CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS = grid_s_outputs
clear_output(wait=False)
print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS)
# Out:
# Top 25 configurations:
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 219, Mean MEE: 8.621673292476268%,
#             training instability coeff validation: 10.560687992944192,
#             training instability coeff train: 6.311110659627067,
#             training loss-val loss diff: 39.42954287484198,
#             Mean Epochs: 219,
#             Mean Test Loss (not rescaled): 0.61161008125937,
#             Std Test Loss (not rescaled): 0.0638485486973228
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 208, Mean MEE: 8.758414418513059%,
#             training instability coeff validation: 15.164325449359746,
#             training instability coeff train: 8.646168375077913,
#             training loss-val loss diff: 43.215754699151184,
#             Mean Epochs: 208,
#             Mean Test Loss (not rescaled): 0.6757779870862837,
#             Std Test Loss (not rescaled): 0.09870904239828791
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 193, Mean MEE: 8.834873546304058%,
#             training instability coeff validation: 11.861920467767401,
#             training instability coeff train: 6.014718776944599,
#             training loss-val loss diff: 43.078528067907406,
#             Mean Epochs: 193,
#             Mean Test Loss (not rescaled): 0.639272795509096,
#             Std Test Loss (not rescaled): 0.08165888849967128
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 178, Mean MEE: 8.85805095938658%,
#             training instability coeff validation: 10.589065868574021,
#             training instability coeff train: 8.05151189657596,
#             training loss-val loss diff: 41.16276093729539,
#             Mean Epochs: 178,
#             Mean Test Loss (not rescaled): 0.6781445730911297,
#             Std Test Loss (not rescaled): 0.0797947663680992
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 200, Mean MEE: 8.88787299715979%,
#             training instability coeff validation: 12.601214028701989,
#             training instability coeff train: 7.549109435775921,
#             training loss-val loss diff: 48.56453656967442,
#             Mean Epochs: 200,
#             Mean Test Loss (not rescaled): 0.6330536864240291,
#             Std Test Loss (not rescaled): 0.0542714680966921
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 185, Mean MEE: 8.901563075797403%,
#             training instability coeff validation: 10.877239754721511,
#             training instability coeff train: 6.3144958175780665,
#             training loss-val loss diff: 43.13123297988541,
#             Mean Epochs: 185,
#             Mean Test Loss (not rescaled): 0.6383139031948042,
#             Std Test Loss (not rescaled): 0.04719612405701615
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 247, Mean MEE: 8.917476398866231%,
#             training instability coeff validation: 13.047407603363983,
#             training instability coeff train: 8.868893849377205,
#             training loss-val loss diff: 43.08530338431946,
#             Mean Epochs: 247,
#             Mean Test Loss (not rescaled): 0.6665768423529854,
#             Std Test Loss (not rescaled): 0.09157025441406273
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 217, Mean MEE: 8.941879201915318%,
#             training instability coeff validation: 12.323143982865748,
#             training instability coeff train: 9.214211609281204,
#             training loss-val loss diff: 49.883647971324194,
#             Mean Epochs: 217,
#             Mean Test Loss (not rescaled): 0.6593277596516145,
#             Std Test Loss (not rescaled): 0.08651685770962984
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 214, Mean MEE: 8.956381739010343%,
#             training instability coeff validation: 13.857970322878206,
#             training instability coeff train: 8.930408016402525,
#             training loss-val loss diff: 46.990581166355,
#             Mean Epochs: 214,
#             Mean Test Loss (not rescaled): 0.6655853639130391,
#             Std Test Loss (not rescaled): 0.1267087015969042
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 230, Mean MEE: 8.96240022467369%,
#             training instability coeff validation: 11.810543605467453,
#             training instability coeff train: 6.180669405114489,
#             training loss-val loss diff: 37.046560502624125,
#             Mean Epochs: 230,
#             Mean Test Loss (not rescaled): 0.6322762927398333,
#             Std Test Loss (not rescaled): 0.06535774473691071
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 247, Mean MEE: 9.00411783059926%,
#             training instability coeff validation: 12.863764051107117,
#             training instability coeff train: 5.820123102550349,
#             training loss-val loss diff: 36.15259377563049,
#             Mean Epochs: 247,
#             Mean Test Loss (not rescaled): 0.6335230436636736,
#             Std Test Loss (not rescaled): 0.06584378011718087
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 161, Mean MEE: 9.007975567902896%,
#             training instability coeff validation: 12.460397670708137,
#             training instability coeff train: 7.105640509432483,
#             training loss-val loss diff: 43.745882576845986,
#             Mean Epochs: 161,
#             Mean Test Loss (not rescaled): 0.6909616031610735,
#             Std Test Loss (not rescaled): 0.10289241026563757
#
# Config index: ([12, 16, 16, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 295, Mean MEE: 9.014606065430266%,
#             training instability coeff validation: 13.02869029432837,
#             training instability coeff train: 5.517631713825959,
#             training loss-val loss diff: 37.58007144576233,
#             Mean Epochs: 295,
#             Mean Test Loss (not rescaled): 0.6755444984972343,
#             Std Test Loss (not rescaled): 0.12277136396182475
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 196, Mean MEE: 9.015596317589194%,
#             training instability coeff validation: 12.088017913496916,
#             training instability coeff train: 4.680687594128985,
#             training loss-val loss diff: 30.426701103311625,
#             Mean Epochs: 196,
#             Mean Test Loss (not rescaled): 0.6761029198230858,
#             Std Test Loss (not rescaled): 0.08371552471452398
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 250, Mean MEE: 9.046498138606532%,
#             training instability coeff validation: 16.31060542787929,
#             training instability coeff train: 7.957820321986992,
#             training loss-val loss diff: 55.62514161292113,
#             Mean Epochs: 250,
#             Mean Test Loss (not rescaled): 0.6722755076716315,
#             Std Test Loss (not rescaled): 0.09651135098582425
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 210, Mean MEE: 9.066140069323627%,
#             training instability coeff validation: 12.10424811926383,
#             training instability coeff train: 8.573453053111937,
#             training loss-val loss diff: 50.953125605536215,
#             Mean Epochs: 210,
#             Mean Test Loss (not rescaled): 0.6818594517541584,
#             Std Test Loss (not rescaled): 0.06517239620251279
#
# Config index: ([12, 32, 32, 32, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 222, Mean MEE: 9.071979079146558%,
#             training instability coeff validation: 14.72209865070052,
#             training instability coeff train: 7.486033918346797,
#             training loss-val loss diff: 42.476667224164885,
#             Mean Epochs: 222,
#             Mean Test Loss (not rescaled): 0.6939900959386816,
#             Std Test Loss (not rescaled): 0.04048970807654142
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 194, Mean MEE: 9.07513033167158%,
#             training instability coeff validation: 11.799930230708057,
#             training instability coeff train: 5.330405461011258,
#             training loss-val loss diff: 43.28735785415753,
#             Mean Epochs: 194,
#             Mean Test Loss (not rescaled): 0.6623908267906298,
#             Std Test Loss (not rescaled): 0.09383031983699747
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 245, Mean MEE: 9.08723952603519%,
#             training instability coeff validation: 14.699961839319235,
#             training instability coeff train: 7.063131837753038,
#             training loss-val loss diff: 46.79326509688106,
#             Mean Epochs: 245,
#             Mean Test Loss (not rescaled): 0.6689386406917962,
#             Std Test Loss (not rescaled): 0.09320751425962923
#
# Config index: ([12, 32, 4], ['tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 269, Mean MEE: 9.112200444021457%,
#             training instability coeff validation: 11.552559208352845,
#             training instability coeff train: 5.129421224024315,
#             training loss-val loss diff: 38.5468091341739,
#             Mean Epochs: 269,
#             Mean Test Loss (not rescaled): 0.6466540232166368,
#             Std Test Loss (not rescaled): 0.0715598386927561
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 243, Mean MEE: 9.122230231054601%,
#             training instability coeff validation: 12.77622991813725,
#             training instability coeff train: 6.719728594748861,
#             training loss-val loss diff: 36.71986585454199,
#             Mean Epochs: 243,
#             Mean Test Loss (not rescaled): 0.6625634062938326,
#             Std Test Loss (not rescaled): 0.06945203059009711
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 232, Mean MEE: 9.136777731494352%,
#             training instability coeff validation: 11.262208166113513,
#             training instability coeff train: 6.872190224867651,
#             training loss-val loss diff: 40.64563598233303,
#             Mean Epochs: 232,
#             Mean Test Loss (not rescaled): 0.6771227173631291,
#             Std Test Loss (not rescaled): 0.08125429055934823
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 173, Mean MEE: 9.16447549852125%,
#             training instability coeff validation: 11.327125282116725,
#             training instability coeff train: 5.451840246169651,
#             training loss-val loss diff: 37.83659240099728,
#             Mean Epochs: 173,
#             Mean Test Loss (not rescaled): 0.6704320413852617,
#             Std Test Loss (not rescaled): 0.05105840540531676
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 194, Mean MEE: 9.189381148796022%,
#             training instability coeff validation: 14.495423666713473,
#             training instability coeff train: 8.185929967593866,
#             training loss-val loss diff: 40.42527260372235,
#             Mean Epochs: 194,
#             Mean Test Loss (not rescaled): 0.7224382655944835,
#             Std Test Loss (not rescaled): 0.05829768816861277
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 225, Mean MEE: 9.199510430134215%,
#             training instability coeff validation: 14.656153720435588,
#             training instability coeff train: 5.363290274570716,
#             training loss-val loss diff: 36.603624402099605,
#             Mean Epochs: 225,
#             Mean Test Loss (not rescaled): 0.7118676434967289,
#             Std Test Loss (not rescaled): 0.08651207780566604

# %% [markdown]
# ### y 2 pred

# %%
y_2 = np.reshape(y_train[:,2], (-1, 1))
train_val_dataset_y2 = DataLoader(X_train, y_2)
k_fold = train_val_dataset_y2.k_fold(k = K_FOLDS)
grid_s_outputs =  grid_search_mlcup(LEN_CONFIGURATIONS, CONFIGURATIONS_OUT_1, k_fold, EPOCHS, EARLY_STOPPING_PATIENCE)
CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF , CONFIG_DICTIONARY_TEST_LOSS= grid_s_outputs
clear_output(wait=False)
print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS)
# Out:
# Top 25 configurations:
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 115, Mean MEE: 11.022137589743087%,
#             training instability coeff validation: 3.772454670724213,
#             training instability coeff train: 1.6783012481148898,
#             training loss-val loss diff: 7.637669452043786,
#             Mean Epochs: 115,
#             Mean Test Loss (not rescaled): 0.35686997136876564,
#             Std Test Loss (not rescaled): 0.03272337265108414
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 105, Mean MEE: 11.040052322362566%,
#             training instability coeff validation: 3.922135115007657,
#             training instability coeff train: 1.3364672059263487,
#             training loss-val loss diff: 5.496870464886455,
#             Mean Epochs: 105,
#             Mean Test Loss (not rescaled): 0.3522944147529043,
#             Std Test Loss (not rescaled): 0.03129537334744645
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 104, Mean MEE: 11.069816296417502%,
#             training instability coeff validation: 3.27421709863023,
#             training instability coeff train: 1.0837856982519627,
#             training loss-val loss diff: 5.476194681998676,
#             Mean Epochs: 104,
#             Mean Test Loss (not rescaled): 0.35040057463886376,
#             Std Test Loss (not rescaled): 0.039313131157343605
#
# Config index: ([12, 16, 4], ['relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 124, Mean MEE: 11.084708807761197%,
#             training instability coeff validation: 3.8680365975994997,
#             training instability coeff train: 1.132673657914767,
#             training loss-val loss diff: 5.693332440477778,
#             Mean Epochs: 124,
#             Mean Test Loss (not rescaled): 0.353646726400868,
#             Std Test Loss (not rescaled): 0.03276038989498149
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 102, Mean MEE: 11.107453393838208%,
#             training instability coeff validation: 4.11524863128299,
#             training instability coeff train: 1.499717234270781,
#             training loss-val loss diff: 9.394053588438263,
#             Mean Epochs: 102,
#             Mean Test Loss (not rescaled): 0.36549879629730625,
#             Std Test Loss (not rescaled): 0.04313088455634852
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 107, Mean MEE: 11.139138907081065%,
#             training instability coeff validation: 2.943846238038124,
#             training instability coeff train: 0.7980744582187533,
#             training loss-val loss diff: 4.827710655869834,
#             Mean Epochs: 107,
#             Mean Test Loss (not rescaled): 0.3498631701649907,
#             Std Test Loss (not rescaled): 0.03927862066495061
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 105, Mean MEE: 11.141630059176356%,
#             training instability coeff validation: 5.811476611426872,
#             training instability coeff train: 2.1068788791836903,
#             training loss-val loss diff: 5.713156165911583,
#             Mean Epochs: 105,
#             Mean Test Loss (not rescaled): 0.3585751545822342,
#             Std Test Loss (not rescaled): 0.04073384654061747
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 104, Mean MEE: 11.147304890210027%,
#             training instability coeff validation: 3.1210894603617505,
#             training instability coeff train: 1.015318511049747,
#             training loss-val loss diff: 7.6209811619777215,
#             Mean Epochs: 104,
#             Mean Test Loss (not rescaled): 0.35836822505023747,
#             Std Test Loss (not rescaled): 0.04384008368575124
#
# Config index: ([12, 16, 16, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 103, Mean MEE: 11.15543407426183%,
#             training instability coeff validation: 3.3501052946068497,
#             training instability coeff train: 0.8981396649894894,
#             training loss-val loss diff: 5.225820493245955,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.35785793546507494,
#             Std Test Loss (not rescaled): 0.05582203304793205
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 112, Mean MEE: 11.17775245868658%,
#             training instability coeff validation: 4.010612657411743,
#             training instability coeff train: 1.1538233414652455,
#             training loss-val loss diff: 6.047632028442486,
#             Mean Epochs: 112,
#             Mean Test Loss (not rescaled): 0.3503798494436509,
#             Std Test Loss (not rescaled): 0.025524341077167622
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 110, Mean MEE: 11.180070224733361%,
#             training instability coeff validation: 4.552361525300138,
#             training instability coeff train: 1.5470794961238326,
#             training loss-val loss diff: 6.8641093628720995,
#             Mean Epochs: 110,
#             Mean Test Loss (not rescaled): 0.36445160336373095,
#             Std Test Loss (not rescaled): 0.04974845287135952
#
# Config index: ([12, 16, 4], ['leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 109, Mean MEE: 11.19691881283209%,
#             training instability coeff validation: 7.642476163692817,
#             training instability coeff train: 2.96996266186707,
#             training loss-val loss diff: 7.483605304385188,
#             Mean Epochs: 109,
#             Mean Test Loss (not rescaled): 0.3666224950154672,
#             Std Test Loss (not rescaled): 0.043334302449009814
#
# Config index: ([12, 16, 4], ['leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 110, Mean MEE: 11.199050445399788%,
#             training instability coeff validation: 3.6821271042531016,
#             training instability coeff train: 1.4485155394621065,
#             training loss-val loss diff: 5.749722805443595,
#             Mean Epochs: 110,
#             Mean Test Loss (not rescaled): 0.358560039693511,
#             Std Test Loss (not rescaled): 0.03450783109911636
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 102, Mean MEE: 11.205262543375195%,
#             training instability coeff validation: 3.438941057001872,
#             training instability coeff train: 1.0734798707418634,
#             training loss-val loss diff: 5.0151802773526555,
#             Mean Epochs: 102,
#             Mean Test Loss (not rescaled): 0.35823745860247996,
#             Std Test Loss (not rescaled): 0.026313412401591196
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 103, Mean MEE: 11.22006234778035%,
#             training instability coeff validation: 3.894456609418987,
#             training instability coeff train: 1.3395602939536002,
#             training loss-val loss diff: 7.695202660591669,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.360892486826343,
#             Std Test Loss (not rescaled): 0.03665905548650033
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 105, Mean MEE: 11.223368686157063%,
#             training instability coeff validation: 3.132901340474085,
#             training instability coeff train: 1.2632869195863894,
#             training loss-val loss diff: 7.730125686251147,
#             Mean Epochs: 105,
#             Mean Test Loss (not rescaled): 0.35700544696212294,
#             Std Test Loss (not rescaled): 0.030194936952334744
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.9, 32), Avg Epochs: 114, Mean MEE: 11.24504288138026%,
#             training instability coeff validation: 6.95756979508123,
#             training instability coeff train: 3.5106707240185955,
#             training loss-val loss diff: 9.976997283267874,
#             Mean Epochs: 114,
#             Mean Test Loss (not rescaled): 0.37480564196491356,
#             Std Test Loss (not rescaled): 0.0636091332682286
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 110, Mean MEE: 11.255780810422978%,
#             training instability coeff validation: 3.8984170809822296,
#             training instability coeff train: 1.3431281040840717,
#             training loss-val loss diff: 6.693297061733057,
#             Mean Epochs: 110,
#             Mean Test Loss (not rescaled): 0.35616370499558775,
#             Std Test Loss (not rescaled): 0.030458787196163125
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 107, Mean MEE: 11.258976409205408%,
#             training instability coeff validation: 5.755110448451001,
#             training instability coeff train: 2.3872646879018045,
#             training loss-val loss diff: 6.736879220024146,
#             Mean Epochs: 107,
#             Mean Test Loss (not rescaled): 0.366050975495528,
#             Std Test Loss (not rescaled): 0.040231081469782326
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 107, Mean MEE: 11.259329745077762%,
#             training instability coeff validation: 3.457898323609451,
#             training instability coeff train: 1.1926432254632693,
#             training loss-val loss diff: 6.9336549865949,
#             Mean Epochs: 107,
#             Mean Test Loss (not rescaled): 0.37408139295926757,
#             Std Test Loss (not rescaled): 0.05292368767165419
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 106, Mean MEE: 11.260732949165554%,
#             training instability coeff validation: 3.6875982594427215,
#             training instability coeff train: 1.4550477410465465,
#             training loss-val loss diff: 7.648190247880477,
#             Mean Epochs: 106,
#             Mean Test Loss (not rescaled): 0.36247068224127904,
#             Std Test Loss (not rescaled): 0.02736899616726913
#
# Config index: ([12, 32, 4], ['leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 108, Mean MEE: 11.266229146485482%,
#             training instability coeff validation: 4.6935320917706695,
#             training instability coeff train: 1.6551004028014291,
#             training loss-val loss diff: 7.032412834368716,
#             Mean Epochs: 108,
#             Mean Test Loss (not rescaled): 0.37411331685797017,
#             Std Test Loss (not rescaled): 0.0446087208451847
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 103, Mean MEE: 11.266579589600997%,
#             training instability coeff validation: 3.0764320877235747,
#             training instability coeff train: 1.1754712175303221,
#             training loss-val loss diff: 4.606974419569154,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.3638114173555546,
#             Std Test Loss (not rescaled): 0.03158339733205796
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 115, Mean MEE: 11.277499095987405%,
#             training instability coeff validation: 3.6197196653589936,
#             training instability coeff train: 1.078907546287556,
#             training loss-val loss diff: 9.989752703927829,
#             Mean Epochs: 115,
#             Mean Test Loss (not rescaled): 0.37234300693462175,
#             Std Test Loss (not rescaled): 0.04024069883512526
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 104, Mean MEE: 11.284895293712804%,
#             training instability coeff validation: 3.2534879172011557,
#             training instability coeff train: 1.0843085837860063,
#             training loss-val loss diff: 5.308254314210555,
#             Mean Epochs: 104,
#             Mean Test Loss (not rescaled): 0.38113144506647173,
#             Std Test Loss (not rescaled): 0.05701221650799533

# %% [markdown]
# ### y 3 pred

# %%
y_3 = np.reshape(y_train[:,3], (-1, 1))
train_val_dataset_y3 = DataLoader(X_train, y_3)
k_fold = train_val_dataset_y3.k_fold(k = K_FOLDS)
grid_s_outputs =  grid_search_mlcup(LEN_CONFIGURATIONS, CONFIGURATIONS_OUT_1, k_fold, EPOCHS, EARLY_STOPPING_PATIENCE)
CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS = grid_s_outputs
clear_output(wait=False)
print_top_25(CONFIG_DICTIONARY, CONFIG_DICTIONARY_EPOCHS, CONFIG_DICTIONARY_INSTABILITY_TRAIN, CONFIG_DICTIONARY_INSTABILITY_VAL, CONFIG_DICTIONARY_TRAIN_LOSS_DIFF, CONFIG_DICTIONARY_TEST_LOSS)
# Out:
# Top 25 configurations:
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 103, Mean MEE: 10.897085615507248%,
#             training instability coeff validation: 2.9299197014922265,
#             training instability coeff train: 0.7752807578057503,
#             training loss-val loss diff: 6.272541554142586,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.36555703122854216,
#             Std Test Loss (not rescaled): 0.04404277889744408
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 111, Mean MEE: 10.912943742680628%,
#             training instability coeff validation: 6.964066342245479,
#             training instability coeff train: 2.384784501962328,
#             training loss-val loss diff: 8.00948539593516,
#             Mean Epochs: 111,
#             Mean Test Loss (not rescaled): 0.3747243531921858,
#             Std Test Loss (not rescaled): 0.06691758821206346
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0.5, 32), Avg Epochs: 109, Mean MEE: 10.918022855401105%,
#             training instability coeff validation: 3.655117046820081,
#             training instability coeff train: 1.2121932070332042,
#             training loss-val loss diff: 7.403606232924112,
#             Mean Epochs: 109,
#             Mean Test Loss (not rescaled): 0.3796943219145219,
#             Std Test Loss (not rescaled): 0.041181790988815754
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 114, Mean MEE: 10.949238968127622%,
#             training instability coeff validation: 2.8820213219647073,
#             training instability coeff train: 0.952284889403835,
#             training loss-val loss diff: 6.5286776761437695,
#             Mean Epochs: 114,
#             Mean Test Loss (not rescaled): 0.35889436754924536,
#             Std Test Loss (not rescaled): 0.034989571840290584
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 126, Mean MEE: 10.992256014433012%,
#             training instability coeff validation: 3.7409182940962125,
#             training instability coeff train: 1.165910485783023,
#             training loss-val loss diff: 8.74595537415264,
#             Mean Epochs: 126,
#             Mean Test Loss (not rescaled): 0.36569521766712265,
#             Std Test Loss (not rescaled): 0.04448522271087168
#
# Config index: ([12, 16, 4], ['leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 103, Mean MEE: 11.040722691528154%,
#             training instability coeff validation: 3.139006039787291,
#             training instability coeff train: 1.0966138603721007,
#             training loss-val loss diff: 5.9791102359455275,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.369222601790865,
#             Std Test Loss (not rescaled): 0.045925241756455334
#
# Config index: ([12, 16, 4], ['tanh', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 107, Mean MEE: 11.072976440168842%,
#             training instability coeff validation: 6.097261360456809,
#             training instability coeff train: 2.004232000447739,
#             training loss-val loss diff: 6.266615655189814,
#             Mean Epochs: 107,
#             Mean Test Loss (not rescaled): 0.37325592386160433,
#             Std Test Loss (not rescaled): 0.029257730826782766
#
# Config index: ([12, 16, 16, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0.0001, 0.9, 32), Avg Epochs: 105, Mean MEE: 11.075582545735326%,
#             training instability coeff validation: 5.667951615038691,
#             training instability coeff train: 2.2512162387738517,
#             training loss-val loss diff: 6.611894614872145,
#             Mean Epochs: 105,
#             Mean Test Loss (not rescaled): 0.3728234585251603,
#             Std Test Loss (not rescaled): 0.05858079578987329
#
# Config index: ([12, 32, 32, 32, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 118, Mean MEE: 11.09083331722301%,
#             training instability coeff validation: 4.505429991494481,
#             training instability coeff train: 1.6739773586313451,
#             training loss-val loss diff: 10.371447053541106,
#             Mean Epochs: 118,
#             Mean Test Loss (not rescaled): 0.3839819012380163,
#             Std Test Loss (not rescaled): 0.049566342804285596
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 107, Mean MEE: 11.09674433847226%,
#             training instability coeff validation: 3.9913685293901096,
#             training instability coeff train: 1.4578515719395717,
#             training loss-val loss diff: 9.551667098099196,
#             Mean Epochs: 107,
#             Mean Test Loss (not rescaled): 0.3708118221125765,
#             Std Test Loss (not rescaled): 0.04525690595532246
#
# Config index: ([12, 16, 16, 16, 4], ['leaky relu', 'leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 122, Mean MEE: 11.103276887340467%,
#             training instability coeff validation: 3.1799179677281337,
#             training instability coeff train: 1.0024595033512964,
#             training loss-val loss diff: 7.958184690130805,
#             Mean Epochs: 122,
#             Mean Test Loss (not rescaled): 0.36946476815171847,
#             Std Test Loss (not rescaled): 0.049882863251851046
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 118, Mean MEE: 11.118291976054142%,
#             training instability coeff validation: 3.9356962256295773,
#             training instability coeff train: 1.3558539962562897,
#             training loss-val loss diff: 7.21646336803573,
#             Mean Epochs: 118,
#             Mean Test Loss (not rescaled): 0.37957621402465336,
#             Std Test Loss (not rescaled): 0.047399198557367406
#
# Config index: ([12, 32, 4], ['tanh', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 102, Mean MEE: 11.119000099966637%,
#             training instability coeff validation: 3.299937723009063,
#             training instability coeff train: 1.164672609571883,
#             training loss-val loss diff: 5.529570556187158,
#             Mean Epochs: 102,
#             Mean Test Loss (not rescaled): 0.3669643825677998,
#             Std Test Loss (not rescaled): 0.03860408375140503
#
# Config index: ([12, 16, 4], ['leaky relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 114, Mean MEE: 11.124576685539285%,
#             training instability coeff validation: 3.9466468595819513,
#             training instability coeff train: 1.4066932083838306,
#             training loss-val loss diff: 6.338842025828255,
#             Mean Epochs: 114,
#             Mean Test Loss (not rescaled): 0.3748355366542958,
#             Std Test Loss (not rescaled): 0.037452709369639306
#
# Config index: ([12, 16, 4], ['tanh', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 116, Mean MEE: 11.135342079279207%,
#             training instability coeff validation: 3.3653250527683527,
#             training instability coeff train: 0.7786039798750564,
#             training loss-val loss diff: 5.5297822511679495,
#             Mean Epochs: 116,
#             Mean Test Loss (not rescaled): 0.36763704384157725,
#             Std Test Loss (not rescaled): 0.04106000939018004
#
# Config index: ([12, 16, 16, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 117, Mean MEE: 11.13694827129521%,
#             training instability coeff validation: 3.2309869623681196,
#             training instability coeff train: 1.1340270686770595,
#             training loss-val loss diff: 6.892169922856664,
#             Mean Epochs: 117,
#             Mean Test Loss (not rescaled): 0.377218691242781,
#             Std Test Loss (not rescaled): 0.06490055640967356
#
# Config index: ([12, 32, 32, 32, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 112, Mean MEE: 11.140408276323459%,
#             training instability coeff validation: 4.152453428002651,
#             training instability coeff train: 1.4753445082022512,
#             training loss-val loss diff: 9.925729897331554,
#             Mean Epochs: 112,
#             Mean Test Loss (not rescaled): 0.3884479351874033,
#             Std Test Loss (not rescaled): 0.06621495039328129
#
# Config index: ([12, 16, 4], ['relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 112, Mean MEE: 11.143319858093474%,
#             training instability coeff validation: 4.542272352743285,
#             training instability coeff train: 1.30841261971737,
#             training loss-val loss diff: 6.377204707074664,
#             Mean Epochs: 112,
#             Mean Test Loss (not rescaled): 0.37405300881784903,
#             Std Test Loss (not rescaled): 0.047705411381833165
#
# Config index: ([12, 32, 4], ['relu', 'identity'], 'mse', 0.001, 1e-06, 0.9, 32), Avg Epochs: 112, Mean MEE: 11.148085701187364%,
#             training instability coeff validation: 7.07567872508969,
#             training instability coeff train: 2.8609038553982,
#             training loss-val loss diff: 10.508140251866816,
#             Mean Epochs: 112,
#             Mean Test Loss (not rescaled): 0.39687015727155717,
#             Std Test Loss (not rescaled): 0.03625701638037928
#
# Config index: ([12, 16, 16, 16, 4], ['relu', 'relu', 'relu', 'identity'], 'mse', 0.001, 1e-06, 0, 32), Avg Epochs: 117, Mean MEE: 11.154665014384712%,
#             training instability coeff validation: 4.619011616582737,
#             training instability coeff train: 1.4107380168877466,
#             training loss-val loss diff: 7.144843741261353,
#             Mean Epochs: 117,
#             Mean Test Loss (not rescaled): 0.3683618823913807,
#             Std Test Loss (not rescaled): 0.04160910124091833
#
# Config index: ([12, 32, 32, 4], ['relu', 'relu', 'identity'], 'mse', 0.001, 0, 0, 32), Avg Epochs: 116, Mean MEE: 11.156094394655293%,
#             training instability coeff validation: 3.5635669759649966,
#             training instability coeff train: 1.0634418991993142,
#             training loss-val loss diff: 9.08082616246789,
#             Mean Epochs: 116,
#             Mean Test Loss (not rescaled): 0.37906101652043994,
#             Std Test Loss (not rescaled): 0.058955049210984045
#
# Config index: ([12, 16, 4], ['leaky relu', 'identity'], 'mse', 0.001, 0, 0.5, 32), Avg Epochs: 108, Mean MEE: 11.157792477722804%,
#             training instability coeff validation: 3.569016498732828,
#             training instability coeff train: 1.0990780538977698,
#             training loss-val loss diff: 6.509666791390581,
#             Mean Epochs: 108,
#             Mean Test Loss (not rescaled): 0.37695847260633186,
#             Std Test Loss (not rescaled): 0.04288109959316399
#
# Config index: ([12, 32, 32, 4], ['tanh', 'tanh', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 103, Mean MEE: 11.172381412984038%,
#             training instability coeff validation: 3.52132878075559,
#             training instability coeff train: 0.9743740731701507,
#             training loss-val loss diff: 4.736672778127044,
#             Mean Epochs: 103,
#             Mean Test Loss (not rescaled): 0.37633236947921367,
#             Std Test Loss (not rescaled): 0.051154890861207614
#
# Config index: ([12, 32, 32, 4], ['leaky relu', 'leaky relu', 'identity'], 'mse', 0.001, 0.0001, 0, 32), Avg Epochs: 106, Mean MEE: 11.173985977597368%,
#             training instability coeff validation: 3.8722441885724637,
#             training instability coeff train: 1.1311224411674856,
#             training loss-val loss diff: 12.302294983557656,
#             Mean Epochs: 106,
#             Mean Test Loss (not rescaled): 0.36980960620945724,
#             Std Test Loss (not rescaled): 0.0392976369415273
#
# Config index: ([12, 16, 16, 16, 4], ['tanh', 'tanh', 'tanh', 'identity'], 'mse', 0.001, 0.0001, 0.5, 32), Avg Epochs: 102, Mean MEE: 11.179545597303491%,
#             training instability coeff validation: 2.948010083317058,
#             training instability coeff train: 0.9342587219228202,
#             training loss-val loss diff: 5.248282397873815,
#             Mean Epochs: 102,
#             Mean Test Loss (not rescaled): 0.3782204963988178,
#             Std Test Loss (not rescaled): 0.035193448620911

# %% [markdown]
# ## Final decision
# We can clearly see that the best 4-output NN performs worse than 4 single-output NNs
# indeed ~20 < ~18. 18 being the square root of the sum of each mee squared
